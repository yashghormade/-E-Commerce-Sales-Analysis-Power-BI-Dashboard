# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r"C:\Users\yash0\Downloads\archive\train.csv", encoding='latin1')
print(df.shape)
print(df.head())
# Out:
# (9800, 18)
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
# Basic info
print("Shape:", df.shape)
print("\nColumns:", df.columns.tolist())
print("\nMissing values:")
print(df.isnull().sum())
print("\nData types:")
print(df.dtypes)
# Out:
# Shape: (9800, 18)
#
# Columns: ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales']
#
# Missing values:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64
#
# Data types:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code      float64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# dtype: object

# %%
print("Shape:", df.shape)
print("\nMissing values:")
print(df.isnull().sum())
# Out:
# Shape: (9800, 18)
#
# Missing values:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
# Date columns  proper format  convert
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# Month and Year column analysis use
df['Order Month'] = df['Order Date'].dt.month
df['Order Year'] = df['Order Date'].dt.year

print("Date columns fixed!")
print(df[['Order Date', 'Ship Date', 'Order Month', 'Order Year']].head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Date columns  proper format  convert
# ----> 2 df['Order Date'] = pd.to_datetime(df['Order Date'])
#       3 df['Ship Date'] = pd.to_datetime(df['Ship Date'])
#       4
#       5 # Month and Year column analysis use
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:254, in _maybe_cache(arg, format, cache, convert_listlike)
#     252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
# --> 254     cache_dates = convert_listlike(unique_dates, format)
#     255     # GH#45319
#     256     try:
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:470, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     459 def _array_strptime_with_fallback(
#     460     arg,
#     461     name,
#    (...)    465     errors: str,
#     466 ) -> Index:
#     467     """
#     468     Call array_strptime, with fallback behavior depending on 'errors'.
#     469     """
# --> 470     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     471     if tz_out is not None:
#     472         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:563, in pandas._libs.tslibs.strptime.array_strptime()
# --> 563 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/strptime.pyx:511, in pandas._libs.tslibs.strptime.array_strptime()
# --> 511 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/tslibs/strptime.pyx:617, in pandas._libs.tslibs.strptime._parse_with_format()
# --> 617 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: time data "15/04/2018" doesn't match format "%m/%d/%Y". You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], dayfirst=True)
df['Ship Date'] = pd.to_datetime(df['Ship Date'], dayfirst=True)

df['Order Month'] = df['Order Date'].dt.month
df['Order Year'] = df['Order Date'].dt.year

print("Date columns fixed!")
print(df[['Order Date', 'Order Month', 'Order Year']].head())
# Out:
# Date columns fixed!
#   Order Date  Order Month  Order Year
# 0 2017-11-08           11        2017
# 1 2017-11-08           11        2017
# 2 2017-06-12            6        2017
# 3 2016-10-11           10        2016
# 4 2016-10-11           10        2016

# %%
# Category wise total sales
category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)
print("Category wise Sales:")
print(category_sales)
# Out:
# Category wise Sales:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
# Chart
plt.figure(figsize=(8, 5))
category_sales.plot(kind='bar', color=['#378ADD', '#EF9F27', '#5DCAA5'])
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Region wise sales
region_sales = df.groupby('Region')['Sales'].sum().sort_values(ascending=False)
print("Region wise Sales:")
print(region_sales)

plt.figure(figsize=(8, 5))
region_sales.plot(kind='bar', color=['#378ADD', '#EF9F27', '#5DCAA5', '#F09595'])
plt.title('Total Sales by Region')
plt.xlabel('Region')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Region wise Sales:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
# Monthly sales trend
monthly_sales = df.groupby(['Order Year', 'Order Month'])['Sales'].sum().reset_index()

plt.figure(figsize=(14, 5))
for year in monthly_sales['Order Year'].unique():
    data = monthly_sales[monthly_sales['Order Year'] == year]
    plt.plot(data['Order Month'], data['Sales'], marker='o', label=str(year))

plt.title('Monthly Sales Trend by Year')
plt.xlabel('Month')
plt.ylabel('Sales ($)')
plt.legend()
plt.xticks(range(1, 13), ['Jan','Feb','Mar','Apr','May','Jun',
                           'Jul','Aug','Sep','Oct','Nov','Dec'])
plt.tight_layout()
plt.show()

# %%
# Top 10 products by sales
top_products = df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(12, 6))
top_products.plot(kind='barh', color='#378ADD')
plt.title('Top 10 Products by Sales')
plt.xlabel('Total Sales ($)')
plt.tight_layout()
plt.show()

# %%
# Segment wise sales
segment_sales = df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)
print(segment_sales)

plt.figure(figsize=(8, 5))
plt.pie(segment_sales, labels=segment_sales.index, autopct='%1.1f%%',
        colors=['#378ADD', '#EF9F27', '#5DCAA5'])
plt.title('Sales by Customer Segment')
plt.tight_layout()
plt.show()
# Out:
# Segment
# Consumer       1.148061e+06
# Corporate      6.884941e+05
# Home Office    4.249822e+05
# Name: Sales, dtype: float64

# %%
# Ship Mode wise sales
ship_sales = df.groupby('Ship Mode')['Sales'].sum().sort_values(ascending=False)
print(ship_sales)

plt.figure(figsize=(8, 5))
ship_sales.plot(kind='bar', color=['#378ADD', '#EF9F27', '#5DCAA5', '#F09595'])
plt.title('Sales by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Ship Mode
# Standard Class    1.340831e+06
# Second Class      4.499142e+05
# First Class       3.455723e+05
# Same Day          1.252190e+05
# Name: Sales, dtype: float64

# %%
df.to_csv('ecommerce_clean.csv', index=False)
print("File saved!")
# Out:
# File saved!

# %%
sub_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sub_sales.plot(kind='bar', color='#378ADD')
plt.title('Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 4
#       1 sub_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)
#       2
#       3 plt.figure(figsize=(12, 6))
# ----> 4 sub_sales.plot(kind='bar', color='#378ADD')
#       5 plt.title('Sales by Sub-Category')
#       6 plt.xlabel('Sub-Category')
#       7 plt.ylabel('Total Sales ($)')
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\pandas\plotting\_core.py:1185, in PlotAccessor.__call__(self, *args, **kwargs)
#    1182             label_name = label_kw or data.columns
#    1183             data.columns = label_name
# -> 1185 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:68, in plot(data, kind, **kwargs)
#      66     if ax is None and len(plt.get_fignums()) > 0:
#      67         with plt.rc_context():
# ---> 68             ax = plt.gca()
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\pyplot.py:2784, in gca()
#    2782 @_copy_docstring_and_deprecators(Figure.gca)
#    2783 def gca() -> Axes:
# -> 2784     return gcf().gca()
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\figure.py:1726, in FigureBase.gca(self)
#    1716 """
#    1717 Get the current Axes.
#    1718
#    (...)   1723 whether `.pyplot.get_fignums()` is empty.)
#    1724 """
#    1725 ax = self._axstack.current()
# -> 1726 return ax if ax is not None else self.add_subplot()
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\figure.py:775, in FigureBase.add_subplot(self, *args, **kwargs)
#     773         args = tuple(map(int, str(args[0])))
#     774     projection_class, pkw = self._process_projection_requirements(**kwargs)
# --> 775     ax = projection_class(self, *args, **pkw)
#     776     key = (projection_class, pkw)
#     777 return self._add_axes_internal(ax, key)
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\axes\_base.py:732, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     729 self.set_axisbelow(mpl.rcParams['axes.axisbelow'])
#     731 self._rasterization_zorder = None
# --> 732 self.clear()
#     734 # funcs used to format x and y - fall back on major formatters
#     735 self.fmt_xdata = None
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\axes\_base.py:1452, in _AxesBase.clear(self)
#    1450     self.cla()
#    1451 else:
# -> 1452     self.__clear()
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\axes\_base.py:1419, in _AxesBase.__clear(self)
#    1415 self.patch.set_transform(self.transAxes)
#    1417 self.set_axis_on()
# -> 1419 self.xaxis.set_clip_path(self.patch)
#    1420 self.yaxis.set_clip_path(self.patch)
#    1422 if self._sharex is not None:
#
# File ~\OneDrive\Desktop\new projects\.venv\Lib\site-packages\matplotlib\axis.py:1115, in Axis.set_clip_path(self, path, transform)
#    1112     kwtrans.update(kw_)
#    1113     return kwtrans
# -> 1115 def set_clip_path(self, path, transform=None):
#    1116     super().set_clip_path(path, transform)
#    1117     for child in self.majorTicks + self.minorTicks:
#
# KeyboardInterrupt:

# %%
plt.close('all')

sub_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sub_sales.plot(kind='bar', color='#378ADD')
plt.title('Sales by Sub-Category')
plt.xlabel('Sub-Category')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.close('all')

yearly_sales = df.groupby('Order Year')['Sales'].sum()
print(yearly_sales)

plt.figure(figsize=(8, 5))
yearly_sales.plot(kind='bar', color=['#378ADD', '#EF9F27', '#5DCAA5', '#F09595'])
plt.title('Yearly Sales Growth')
plt.xlabel('Year')
plt.ylabel('Total Sales ($)')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# Order Year
# 2015    479856.2081
# 2016    459436.0054
# 2017    600192.5500
# 2018    722052.0192
# Name: Sales, dtype: float64

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\yash0\OneDrive\Desktop\new projects
